# %% [markdown]
# # Exercicio 1
#
#
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ##### Quantum Finance - Projeto Integrado - Apresentação de aplicação em Inteligência Artificial/Machine Learning  (Turma 5DTS)
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ##### Dataset: https://www.kaggle.com/datasets/parisrohan/credit-score-classification
#
# #### 1-    Criar um modelo de classificação, aplicar na base, colher e explicar os resultados.

# %% [markdown]
# ### Libs importadas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sns
from feature_engine.encoding import CountFrequencyEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Leitura da base

# %%
###Lendo a base de dados
data =  pd.read_csv('https://raw.githubusercontent.com/scudellerlemos/Machine-Learning-Projects/main/Kaggle%20Challenges/credit_train.csv',sep=',')
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\4093521193.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   data =  pd.read_csv('https://raw.githubusercontent.com/scudellerlemos/Machine-Learning-Projects/main/Kaggle%20Challenges/credit_train.csv',sep=',')

# %%
#Amostra
data.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Engenharia e limpeza dos dados

# %%
#selecionar colunas do tipo texto e exibir as colunas
data.select_dtypes(include='object').columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Num_of_Loan', 'Type_of_Loan',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
data.select_dtypes(include='object')
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income Num_of_Loan  \
# 0      Scientist      19114.12           4
# 1      Scientist      19114.12           4
# 2      Scientist      19114.12           4
# 3      Scientist      19114.12           4
# 4      Scientist      19114.12           4
# ...          ...           ...         ...
# 99995   Mechanic      39628.99           2
# 99996   Mechanic      39628.99           2
# 99997   Mechanic      39628.99           2
# 99998   Mechanic      39628.99           2
# 99999   Mechanic     39628.99_           2
#
#                                             Type_of_Loan  \
# 0      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...
# ...                                                  ...
# 99995                        Auto Loan, and Student Loan
# 99996                        Auto Loan, and Student Loan
# 99997                        Auto Loan, and Student Loan
# 99998                        Auto Loan, and Student Loan
# 99999                        Auto Loan, and Student Loan
#
#       Num_of_Delayed_Payment Changed_Credit_Limit Credit_Mix Outstanding_Debt  \
# 0                          7                11.27          _           809.98
# 1                        NaN                11.27       Good           809.98
# 2                          7                    _       Good           809.98
# 3                          4                 6.27       Good           809.98
# 4                        NaN                11.27       Good           809.98
# ...                      ...                  ...        ...              ...
# 99995                      7                 11.5          _           502.38
# 99996                      7                 11.5          _           502.38
# 99997                      6                 11.5       Good           502.38
# 99998                    NaN                 11.5       Good           502.38
# 99999                      6                 11.5       Good           502.38
#
#            Credit_History_Age Payment_of_Min_Amount Amount_invested_monthly  \
# 0       22 Years and 1 Months                    No       80.41529543900253
# 1                         NaN                    No      118.28022162236736
# 2       22 Years and 3 Months                    No         81.699521264648
# 3       22 Years and 4 Months                    No       199.4580743910713
# 4       22 Years and 5 Months                    No      41.420153086217326
# ...                       ...                   ...                     ...
# 99995   31 Years and 6 Months                    No       60.97133255718485
# 99996   31 Years and 7 Months                    No       54.18595028760385
# 99997   31 Years and 8 Months                    No       24.02847744864441
# 99998   31 Years and 9 Months                    No      251.67258219721603
# 99999  31 Years and 10 Months                    No       167.1638651610451
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score
# 0       High_spent_Small_value_payments  312.49408867943663         Good
# 1        Low_spent_Large_value_payments  284.62916249607184         Good
# 2       Low_spent_Medium_value_payments   331.2098628537912         Good
# 3        Low_spent_Small_value_payments  223.45130972736786         Good
# 4      High_spent_Medium_value_payments  341.48923103222177         Good
# ...                                 ...                 ...          ...
# 99995   High_spent_Large_value_payments          479.866228         Poor
# 99996  High_spent_Medium_value_payments           496.65161         Poor
# 99997   High_spent_Large_value_payments          516.809083         Poor
# 99998    Low_spent_Large_value_payments          319.164979     Standard
# 99999                            !@9#%8          393.673696         Poor
#
# [100000 rows x 20 columns]

# %%
#listar as colunas do tipo numero ou que deveriam ser numeros
lista_colunas_tratar_num=['Age','Monthly_Inhand_Salary','Annual_Income','Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Loan','Num_of_Delayed_Payment','Delay_from_due_date','Num_Credit_Inquiries','Changed_Credit_Limit','Outstanding_Debt','Credit_History_Age','Credit_Utilization_Ratio','Amount_invested_monthly','Monthly_Balance','Total_EMI_per_month']

# %%
#colunas do tipo texto
colunas_texto_tratar = [coluna for coluna in data.columns if coluna not in lista_colunas_tratar_num]

# %%
data[lista_colunas_tratar_num]
# Out:
#         Age  Monthly_Inhand_Salary Annual_Income  Num_Bank_Accounts  \
# 0        23            1824.843333      19114.12                  3
# 1        23                    NaN      19114.12                  3
# 2      -500                    NaN      19114.12                  3
# 3        23                    NaN      19114.12                  3
# 4        23            1824.843333      19114.12                  3
# ...     ...                    ...           ...                ...
# 99995    25            3359.415833      39628.99                  4
# 99996    25            3359.415833      39628.99                  4
# 99997    25            3359.415833      39628.99                  4
# 99998    25            3359.415833      39628.99                  4
# 99999    25            3359.415833     39628.99_                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan Num_of_Delayed_Payment  \
# 0                    4              3           4                      7
# 1                    4              3           4                    NaN
# 2                    4              3           4                      7
# 3                    4              3           4                      4
# 4                    4              3           4                    NaN
# ...                ...            ...         ...                    ...
# 99995                6              7           2                      7
# 99996                6              7           2                      7
# 99997                6           5729           2                      6
# 99998                6              7           2                    NaN
# 99999                6              7           2                      6
#
#        Delay_from_due_date  Num_Credit_Inquiries Changed_Credit_Limit  \
# 0                        3                   4.0                11.27
# 1                       -1                   4.0                11.27
# 2                        3                   4.0                    _
# 3                        5                   4.0                 6.27
# 4                        6                   4.0                11.27
# ...                    ...                   ...                  ...
# 99995                   23                   3.0                 11.5
# 99996                   18                   3.0                 11.5
# 99997                   27                   3.0                 11.5
# 99998                   20                   3.0                 11.5
# 99999                   18                   3.0                 11.5
#
#       Outstanding_Debt      Credit_History_Age  Credit_Utilization_Ratio  \
# 0               809.98   22 Years and 1 Months                 26.822620
# 1               809.98                     NaN                 31.944960
# 2               809.98   22 Years and 3 Months                 28.609352
# 3               809.98   22 Years and 4 Months                 31.377862
# 4               809.98   22 Years and 5 Months                 24.797347
# ...                ...                     ...                       ...
# 99995           502.38   31 Years and 6 Months                 34.663572
# 99996           502.38   31 Years and 7 Months                 40.565631
# 99997           502.38   31 Years and 8 Months                 41.255522
# 99998           502.38   31 Years and 9 Months                 33.638208
# 99999           502.38  31 Years and 10 Months                 34.192463
#
#       Amount_invested_monthly     Monthly_Balance  Total_EMI_per_month
# 0           80.41529543900253  312.49408867943663            49.574949
# 1          118.28022162236736  284.62916249607184            49.574949
# 2             81.699521264648   331.2098628537912            49.574949
# 3           199.4580743910713  223.45130972736786            49.574949
# 4          41.420153086217326  341.48923103222177            49.574949
# ...                       ...                 ...                  ...
# 99995       60.97133255718485          479.866228            35.104023
# 99996       54.18595028760385           496.65161            35.104023
# 99997       24.02847744864441          516.809083            35.104023
# 99998      251.67258219721603          319.164979            35.104023
# 99999       167.1638651610451          393.673696            35.104023
#
# [100000 rows x 17 columns]

# %%
data[colunas_texto_tratar]
# Out:
#             ID Customer_ID     Month           Name          SSN Occupation  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh  821-00-0265  Scientist
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh  821-00-0265  Scientist
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  821-00-0265  Scientist
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh  821-00-0265  Scientist
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh  821-00-0265  Scientist
# ...        ...         ...       ...            ...          ...        ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks  078-73-5990   Mechanic
# 99996  0x25fea  CUS_0x942c       May          Nicks  078-73-5990   Mechanic
# 99997  0x25feb  CUS_0x942c      June          Nicks  078-73-5990   Mechanic
# 99998  0x25fec  CUS_0x942c      July          Nicks  078-73-5990   Mechanic
# 99999  0x25fed  CUS_0x942c    August          Nicks  078-73-5990   Mechanic
#
#                                             Type_of_Loan Credit_Mix  \
# 0      Auto Loan, Credit-Builder Loan, Personal Loan,...          _
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 2      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 3      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# ...                                                  ...        ...
# 99995                        Auto Loan, and Student Loan          _
# 99996                        Auto Loan, and Student Loan          _
# 99997                        Auto Loan, and Student Loan       Good
# 99998                        Auto Loan, and Student Loan       Good
# 99999                        Auto Loan, and Student Loan       Good
#
#       Payment_of_Min_Amount                 Payment_Behaviour Credit_Score
# 0                        No   High_spent_Small_value_payments         Good
# 1                        No    Low_spent_Large_value_payments         Good
# 2                        No   Low_spent_Medium_value_payments         Good
# 3                        No    Low_spent_Small_value_payments         Good
# 4                        No  High_spent_Medium_value_payments         Good
# ...                     ...                               ...          ...
# 99995                    No   High_spent_Large_value_payments         Poor
# 99996                    No  High_spent_Medium_value_payments         Poor
# 99997                    No   High_spent_Large_value_payments         Poor
# 99998                    No    Low_spent_Large_value_payments     Standard
# 99999                    No                            !@9#%8         Poor
#
# [100000 rows x 11 columns]

# %%
#criação do dataset das features categoricas
data_texto = data[colunas_texto_tratar]

# %%
#criação do dataset das colunas numericas
data_num = data[lista_colunas_tratar_num]

# %%
##exploração do dataset numerico

data_explore=pd.DataFrame(((data_num.isnull().sum()/data_num.shape[0])*100))

# %%
##exibição dos campos nulos

data_explore[data_explore[0]>0]
# Out:
#                               0
# Monthly_Inhand_Salary    15.002
# Num_of_Delayed_Payment    7.002
# Num_Credit_Inquiries      1.965
# Credit_History_Age        9.030
# Amount_invested_monthly   4.479
# Monthly_Balance           1.200

# %%
data[list(data_explore[data_explore[0]>0].index)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Monthly_Inhand_Salary    84998 non-null  float64
#  1   Num_of_Delayed_Payment   92998 non-null  object
#  2   Num_Credit_Inquiries     98035 non-null  float64
#  3   Credit_History_Age       90970 non-null  object
#  4   Amount_invested_monthly  95521 non-null  object
#  5   Monthly_Balance          98800 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 4.6+ MB

# %%
data_num.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Age                      100000 non-null  object
#  1   Annual_Income            100000 non-null  object
#  2   Num_of_Loan              100000 non-null  object
#  3   Num_of_Delayed_Payment   92998 non-null   object
#  4   Changed_Credit_Limit     100000 non-null  object
#  5   Outstanding_Debt         100000 non-null  object
#  6   Credit_History_Age       90970 non-null   object
#  7   Amount_invested_monthly  95521 non-null   object
#  8   Monthly_Balance          98800 non-null   object
# dtypes: object(9)
# memory usage: 6.9+ MB

# %%
def corrigir_idade(age_str):
    age_values = [int(age) for age in re.findall(r'\d+', age_str) if 0 <= int(age) < 80]
    return age_values[0] if age_values else None

# %%
# Aplicar a função de extração de idade à coluna 'Age'
data_num['Age'] = data_num['Age'].apply(corrigir_idade).ffill().astype('Int64')
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\2235487868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num['Age'] = data_num['Age'].apply(corrigir_idade).ffill().astype('Int64')

# %%
idade = data_num['Age']

plt.figure(figsize=(10, 6))
ax = plt.gca()

# Plotar de idade
plt.hist(idade, bins=20, edgecolor='black', alpha=0.7, color='skyblue')

# rótulos e título
plt.xlabel('Idade')
plt.ylabel('Número de Pessoas')
plt.title('Distribuição de Idades ')

# grade no eixo Y
ax.yaxis.grid(True, linestyle='--', alpha=0.6)


plt.show()

# %%
def conversor_dias(history_age):
    if history_age == 'NA':
        return None

    try:
        parts = history_age.split(' ')
        years = int(parts[0])
        months = int(parts[3])

        # Calcular o total de dias (aproximadamente considerando 30 dias por mês)
        total_days = years * 365 + months * 30

        return total_days
    except (ValueError, IndexError):
        # Tratar erros de conversão ou índices inválidos
        return None

# %%
data_num['Credit_History_Age']
# Out:
# 0         22 Years and 1 Months
# 1                           NaN
# 2         22 Years and 3 Months
# 3         22 Years and 4 Months
# 4         22 Years and 5 Months
#                   ...
# 99995     31 Years and 6 Months
# 99996     31 Years and 7 Months
# 99997     31 Years and 8 Months
# 99998     31 Years and 9 Months
# 99999    31 Years and 10 Months
# Name: Credit_History_Age, Length: 100000, dtype: object

# %%
data_num['Credit_History_Age'] = data_num['Credit_History_Age'].astype(str)
data_num['Credit_History_Age_Days'] = data_num['Credit_History_Age'].apply(conversor_dias)
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\3779112071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num['Credit_History_Age'] = data_num['Credit_History_Age'].astype(str)
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\3779112071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num['Credit_History_Age_Days'] = data_num['Credit_History_Age'].apply(conversor_dias)

# %%
data_num['Credit_History_Age_Days']
# Out:
# 0         8060.0
# 1            NaN
# 2         8120.0
# 3         8150.0
# 4         8180.0
#           ...
# 99995    11495.0
# 99996    11525.0
# 99997    11555.0
# 99998    11585.0
# 99999    11615.0
# Name: Credit_History_Age_Days, Length: 100000, dtype: float64

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       100000 non-null  Int64
#  1   Monthly_Inhand_Salary     84998 non-null   float64
#  2   Annual_Income             100000 non-null  object
#  3   Num_Bank_Accounts         100000 non-null  int64
#  4   Num_Credit_Card           100000 non-null  int64
#  5   Interest_Rate             100000 non-null  int64
#  6   Num_of_Loan               100000 non-null  object
#  7   Num_of_Delayed_Payment    92998 non-null   object
#  8   Delay_from_due_date       100000 non-null  int64
#  9   Num_Credit_Inquiries      98035 non-null   float64
#  10  Changed_Credit_Limit      100000 non-null  object
#  11  Outstanding_Debt          100000 non-null  object
#  12  Credit_History_Age        100000 non-null  object
#  13  Credit_Utilization_Ratio  100000 non-null  float64
#  14  Amount_invested_monthly   95521 non-null   object
#  15  Monthly_Balance           98800 non-null   object
#  16  Total_EMI_per_month       100000 non-null  float64
#  17  Credit_History_Age_Days   90970 non-null   float64
# dtypes: Int64(1), float64(5), int64(4), object(8)
# memory usage: 13.8+ MB

# %%
data_num.select_dtypes(include='object').columns
# Out:
# Index(['Annual_Income', 'Num_of_Loan', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Outstanding_Debt', 'Credit_History_Age',
#        'Amount_invested_monthly', 'Monthly_Balance'],
#       dtype='object')

# %%
data_num[data_num.select_dtypes(include='object').columns].astype(str)
# Out:
#       Annual_Income Num_of_Loan Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0          19114.12           4                      7                11.27
# 1          19114.12           4                    nan                11.27
# 2          19114.12           4                      7                    _
# 3          19114.12           4                      4                 6.27
# 4          19114.12           4                    nan                11.27
# ...             ...         ...                    ...                  ...
# 99995      39628.99           2                      7                 11.5
# 99996      39628.99           2                      7                 11.5
# 99997      39628.99           2                      6                 11.5
# 99998      39628.99           2                    nan                 11.5
# 99999     39628.99_           2                      6                 11.5
#
#       Outstanding_Debt      Credit_History_Age Amount_invested_monthly  \
# 0               809.98   22 Years and 1 Months       80.41529543900253
# 1               809.98                     nan      118.28022162236736
# 2               809.98   22 Years and 3 Months         81.699521264648
# 3               809.98   22 Years and 4 Months       199.4580743910713
# 4               809.98   22 Years and 5 Months      41.420153086217326
# ...                ...                     ...                     ...
# 99995           502.38   31 Years and 6 Months       60.97133255718485
# 99996           502.38   31 Years and 7 Months       54.18595028760385
# 99997           502.38   31 Years and 8 Months       24.02847744864441
# 99998           502.38   31 Years and 9 Months      251.67258219721603
# 99999           502.38  31 Years and 10 Months       167.1638651610451
#
#           Monthly_Balance
# 0      312.49408867943663
# 1      284.62916249607184
# 2       331.2098628537912
# 3      223.45130972736786
# 4      341.48923103222177
# ...                   ...
# 99995  479.86622816574095
# 99996    496.651610435322
# 99997   516.8090832742814
# 99998   319.1649785257098
# 99999   393.6736955618808
#
# [100000 rows x 8 columns]

# %%
data_num[data_num.select_dtypes(include='object').columns] = data_num[data_num.select_dtypes(include='object').columns].replace('_', '', regex=True)
data_num[data_num.select_dtypes(include='object').columns] = data_num[data_num.select_dtypes(include='object').columns].apply(pd.to_numeric,errors='coerce')
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\3846901261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num[data_num.select_dtypes(include='object').columns] = data_num[data_num.select_dtypes(include='object').columns].replace('_', '', regex=True)
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\3846901261.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num[data_num.select_dtypes(include='object').columns] = data_num[data_num.select_dtypes(include='object').columns].apply(pd.to_numeric,errors='coerce')

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       100000 non-null  Int64
#  1   Monthly_Inhand_Salary     84998 non-null   float64
#  2   Annual_Income             100000 non-null  float64
#  3   Num_Bank_Accounts         100000 non-null  int64
#  4   Num_Credit_Card           100000 non-null  int64
#  5   Interest_Rate             100000 non-null  int64
#  6   Num_of_Loan               100000 non-null  int64
#  7   Num_of_Delayed_Payment    92998 non-null   float64
#  8   Delay_from_due_date       100000 non-null  int64
#  9   Num_Credit_Inquiries      98035 non-null   float64
#  10  Changed_Credit_Limit      97909 non-null   float64
#  11  Outstanding_Debt          100000 non-null  float64
#  12  Credit_History_Age        0 non-null       float64
#  13  Credit_Utilization_Ratio  100000 non-null  float64
#  14  Amount_invested_monthly   95521 non-null   float64
#  15  Monthly_Balance           98800 non-null   float64
#  16  Total_EMI_per_month       100000 non-null  float64
#  17  Credit_History_Age_Days   90970 non-null   float64
# dtypes: Int64(1), float64(12), int64(5)
# memory usage: 13.8 MB

# %%
data_num.drop('Credit_History_Age',axis=1,inplace=True)
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\1267242665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_num.drop('Credit_History_Age',axis=1,inplace=True)

# %%
data_num.describe().T
# Out:
#                              count                       mean  \
# Age                       100000.0                   33.31799
# Monthly_Inhand_Salary      84998.0                 4194.17085
# Annual_Income             100000.0              176415.701298
# Num_Bank_Accounts         100000.0                   17.09128
# Num_Credit_Card           100000.0                   22.47443
# Interest_Rate             100000.0                   72.46604
# Num_of_Loan               100000.0                    3.00996
# Num_of_Delayed_Payment     92998.0                  30.923342
# Delay_from_due_date       100000.0                   21.06878
# Num_Credit_Inquiries       98035.0                  27.754251
# Changed_Credit_Limit       97909.0                  10.389025
# Outstanding_Debt          100000.0                1426.220376
# Credit_Utilization_Ratio  100000.0                  32.285173
# Amount_invested_monthly    95521.0                 637.412998
# Monthly_Balance            98800.0 -30364372469635625254912.0
# Total_EMI_per_month       100000.0                1403.118217
# Credit_History_Age_Days    90970.0                6725.694735
#
#                                                   std  \
# Age                                          10.76921
# Monthly_Inhand_Salary                     3183.686167
# Annual_Income                          1429618.051414
# Num_Bank_Accounts                          117.404834
# Num_Credit_Card                             129.05741
# Interest_Rate                              466.422621
# Num_of_Loan                                 62.647879
# Num_of_Delayed_Payment                     226.031892
# Delay_from_due_date                         14.860104
# Num_Credit_Inquiries                       193.177339
# Changed_Credit_Limit                         6.789496
# Outstanding_Debt                          1155.129026
# Credit_Utilization_Ratio                     5.116875
# Amount_invested_monthly                   2043.319327
# Monthly_Balance           3181295008384109317718016.0
# Total_EMI_per_month                        8306.04127
# Credit_History_Age_Days                   3033.815719
#
#                                                     min          25%  \
# Age                                                14.0         24.0
# Monthly_Inhand_Salary                        303.645417  1625.568229
# Annual_Income                                   7005.93      19457.5
# Num_Bank_Accounts                                  -1.0          3.0
# Num_Credit_Card                                     0.0          4.0
# Interest_Rate                                       1.0          8.0
# Num_of_Loan                                      -100.0          1.0
# Num_of_Delayed_Payment                             -3.0          9.0
# Delay_from_due_date                                -5.0         10.0
# Num_Credit_Inquiries                                0.0          3.0
# Changed_Credit_Limit                              -6.49         5.32
# Outstanding_Debt                                   0.23     566.0725
# Credit_Utilization_Ratio                           20.0    28.052567
# Amount_invested_monthly                             0.0    74.534002
# Monthly_Balance          -333333333333333314856026112.0   270.092209
# Total_EMI_per_month                                 0.0     30.30666
# Credit_History_Age_Days                            30.0       4380.0
#
#                                  50%          75%           max
# Age                             33.0         42.0          56.0
# Monthly_Inhand_Salary       3093.745  5957.448333  15204.633333
# Annual_Income               37578.61     72790.92    24198062.0
# Num_Bank_Accounts                6.0          7.0        1798.0
# Num_Credit_Card                  5.0          7.0        1499.0
# Interest_Rate                   13.0         20.0        5797.0
# Num_of_Loan                      3.0          5.0        1496.0
# Num_of_Delayed_Payment          14.0         18.0        4397.0
# Delay_from_due_date             18.0         28.0          67.0
# Num_Credit_Inquiries             6.0          9.0        2597.0
# Changed_Credit_Limit             9.4        14.87         36.97
# Outstanding_Debt            1166.155    1945.9625       4998.07
# Credit_Utilization_Ratio   32.305784    36.496663          50.0
# Amount_invested_monthly   135.925682   265.731733       10000.0
# Monthly_Balance            336.71919   470.220186   1602.040519
# Total_EMI_per_month        69.249473   161.224249       82331.0
# Credit_History_Age_Days       6660.0       9185.0       12285.0

# %%
###inicio de tratamento das colunas categoricas
data_texto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     100000 non-null  object
#  1   Customer_ID            100000 non-null  object
#  2   Month                  100000 non-null  object
#  3   Name                   90015 non-null   object
#  4   SSN                    100000 non-null  object
#  5   Occupation             100000 non-null  object
#  6   Type_of_Loan           88592 non-null   object
#  7   Credit_Mix             100000 non-null  object
#  8   Payment_of_Min_Amount  100000 non-null  object
#  9   Payment_Behaviour      100000 non-null  object
#  10  Credit_Score           100000 non-null  object
# dtypes: object(11)
# memory usage: 8.4+ MB

# %%
unique_occupations = data_texto['Occupation'].unique()
print(unique_occupations)
# Out:
# ['Scientist' '_______' 'Teacher' 'Engineer' 'Entrepreneur' 'Developer'
#  'Lawyer' 'Media_Manager' 'Doctor' 'Journalist' 'Manager' 'Accountant'
#  'Musician' 'Mechanic' 'Writer' 'Architect']

# %%
#Tratando Occupation
# Substituir valores específicos por pd.NA
data_texto['Occupation'] = data_texto['Occupation'].replace('_______', pd.NA)

# Agrupar por 'Customer_ID' e aplicar transform para encontrar a ocupação mais comum
data_texto['Co_Occupation'] = data_texto.groupby('Customer_ID')['Occupation'].transform(lambda x: x.mode().iat[0])

data_texto.drop(columns=['Occupation'], inplace=True)

# Renomear a nova coluna para 'Occupation'
data_texto.rename(columns={'Co_Occupation': 'Occupation'}, inplace=True)
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\4209042105.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_texto['Occupation'] = data_texto['Occupation'].replace('_______', pd.NA)
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\4209042105.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_texto['Co_Occupation'] = data_texto.groupby('Customer_ID')['Occupation'].transform(lambda x: x.mode().iat[0])
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\4209042105.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_texto.drop(columns=['Occupation'], inplace=True)
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\4209042105.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_texto.rename(columns={'Co_Occupation': 'Occupation'}, inplace=True)

# %%
data_texto['Occupation'].unique()
# Out:
# array(['Scientist', 'Teacher', 'Engineer', 'Entrepreneur', 'Developer',
#        'Lawyer', 'Media_Manager', 'Doctor', 'Journalist', 'Manager',
#        'Accountant', 'Musician', 'Mechanic', 'Writer', 'Architect'],
#       dtype=object)

# %%
#Tratamento para Type_of_Loan para valores nulos
data_texto['Type_of_Loan'].fillna('Unknown_Loan', inplace=True)
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\585374682.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_texto['Type_of_Loan'].fillna('Unknown_Loan', inplace=True)

# %%
#Tratamento das colunas de  Credit_Mix
data_texto['Credit_Mix'].unique()
# Out:
# array(['_', 'Good', 'Standard', 'Bad'], dtype=object)

# %%
data_texto['Credit_Mix'] = data_texto['Credit_Mix'].str.replace('_', 'Unknown_credit_mix')
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\1707607667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_texto['Credit_Mix'] = data_texto['Credit_Mix'].str.replace('_', 'Unknown_credit_mix')

# %%
data_texto['Credit_Mix'].unique()
# Out:
# array(['Unknown_credit_mix', 'Good', 'Standard', 'Bad'], dtype=object)

# %%
#Tratamento das colunas de  Payment_Behaviour
data_texto['Payment_Behaviour'].unique()
# Out:
# array(['High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments',
#        'Low_spent_Medium_value_payments',
#        'Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments', '!@9#%8',
#        'High_spent_Large_value_payments'], dtype=object)

# %%
data_texto['Payment_Behaviour'] = data_texto['Payment_Behaviour'].str.replace('!@9#%8', 'Unknown_Payment_Behaviour')
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_2616\3779601635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_texto['Payment_Behaviour'] = data_texto['Payment_Behaviour'].str.replace('!@9#%8', 'Unknown_Payment_Behaviour')

# %%
data_texto['Payment_Behaviour'].unique()
# Out:
# array(['High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments',
#        'Low_spent_Medium_value_payments',
#        'Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments', 'Unknown_Payment_Behaviour',
#        'High_spent_Large_value_payments'], dtype=object)

# %%
data_antes_treinar = pd.concat([data_texto,data_num],axis=1)

# %%
###Completando os campos nulos das colunas numericas, sendo segmentado pelo grão mais baixo (granularidade mais baixa = Customer_ID)#######

data_fill = data_antes_treinar.copy()

colunas_numericas = data_num.columns

for coluna in colunas_numericas:
     data_fill[coluna] = data_fill.groupby('Customer_ID')[coluna].transform(lambda x: x.fillna(x.median()))

# %%
##Checar valores nulos restantes do dataset
data_fill.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        9985
# SSN                            0
# Type_of_Loan                   0
# Credit_Mix                     0
# Payment_of_Min_Amount          0
# Payment_Behaviour              0
# Credit_Score                   0
# Occupation                     0
# Age                            0
# Monthly_Inhand_Salary          0
# Annual_Income                  0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Num_of_Delayed_Payment         0
# Delay_from_due_date            0
# Num_Credit_Inquiries           0
# Changed_Credit_Limit           0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Amount_invested_monthly        0
# Monthly_Balance                0
# Total_EMI_per_month            0
# Credit_History_Age_Days        0
# dtype: int64

# %% [markdown]
# ### Entendendo e Mapeando o Target

# %%
###Conhecendo os valores do TARGET ######
data_fill['Credit_Score'].unique()
# Out:
# array(['Good', 'Standard', 'Poor'], dtype=object)

# %%
#### DEFININDO VALORES DE TARGET####
#   Poor = 0
#   Standard = 1 
#   Good = 2


# Definir o mapeamento
map_credit_score = {
    'Poor': 0,
    'Standard': 1,
    'Good': 2
}

# Aplicar o mapeamento à coluna 'Credit_Score'
data_fill['Credit_Score'] = data_fill['Credit_Score'].map(map_credit_score)

# %% [markdown]
# ### Separação de Features e Target

# %%
X = data_fill.drop(['ID', 'Customer_ID', 'Name', 'SSN','Credit_Score'], axis=1)
Y = data_fill['Credit_Score']

# %% [markdown]
# #### Encoding

# %%
######ENCODING FEATURES###############


##Transformando os dados categoricos em frequencias
encoder = CountFrequencyEncoder(encoding_method='frequency',
                         variables=list(X.select_dtypes(include='object').columns))
# Treinar o encoder
encoder.fit(X)

# Transformar os dados
X_encoded= encoder.transform(X)


encoder.encoder_dict_
# Out:
# {'Month': {'January': 0.125,
#   'February': 0.125,
#   'March': 0.125,
#   'April': 0.125,
#   'May': 0.125,
#   'June': 0.125,
#   'July': 0.125,
#   'August': 0.125},
#  'Type_of_Loan': {'Unknown_Loan': 0.11408,
#   'Not Specified': 0.01408,
#   'Credit-Builder Loan': 0.0128,
#   'Personal Loan': 0.01272,
#   'Debt Consolidation Loan': 0.01264,
#   'Student Loan': 0.0124,
#   'Payday Loan': 0.012,
#   'Mortgage Loan': 0.01176,
#   'Auto Loan': 0.01152,
#   'Home Equity Loan': 0.01136,
#   'Personal Loan, and Student Loan': 0.0032,
#   'Not Specified, and Payday Loan': 0.00272,
#   'Mortgage Loan, and Home Equity Loan': 0.00264,
#   'Student Loan, and Payday Loan': 0.00256,
#   'Student Loan, and Credit-Builder Loan': 0.00248,
#   'Credit-Builder Loan, and Not Specified': 0.00248,
#   'Payday Loan, and Debt Consolidation Loan': 0.0024,
#   'Payday Loan, and Auto Loan': 0.0024,
#   'Mortgage Loan, and Not Specified': 0.00232,
#   'Payday Loan, and Personal Loan': 0.00232,
#   'Auto Loan, and Personal Loan': 0.00232,
#   'Payday Loan, and Student Loan': 0.00232,
#   'Credit-Builder Loan, and Mortgage Loan': 0.00232,
#   'Personal Loan, and Credit-Builder Loan': 0.00232,
#   'Auto Loan, and Payday Loan': 0.00224,
#   'Debt Consolidation Loan, and Home Equity Loan': 0.00224,
#   'Not Specified, and Auto Loan': 0.00216,
#   'Home Equity Loan, and Student Loan': 0.00216,
#   'Home Equity Loan, and Not Specified': 0.00216,
#   'Student Loan, and Student Loan': 0.00216,
#   'Credit-Builder Loan, and Auto Loan': 0.00216,
#   'Auto Loan, and Debt Consolidation Loan': 0.00216,
#   'Debt Consolidation Loan, and Payday Loan': 0.00216,
#   'Mortgage Loan, and Student Loan': 0.00216,
#   'Credit-Builder Loan, and Home Equity Loan': 0.00216,
#   'Student Loan, and Auto Loan': 0.00208,
#   'Home Equity Loan, and Mortgage Loan': 0.00208,
#   'Credit-Builder Loan, and Debt Consolidation Loan': 0.00208,
#   'Not Specified, and Credit-Builder Loan': 0.00208,
#   'Personal Loan, and Debt Consolidation Loan': 0.00208,
#   'Personal Loan, and Not Specified': 0.00208,
#   'Not Specified, and Debt Consolidation Loan': 0.002,
#   'Mortgage Loan, and Mortgage Loan': 0.002,
#   'Debt Consolidation Loan, and Debt Consolidation Loan': 0.002,
#   'Home Equity Loan, and Debt Consolidation Loan': 0.002,
#   'Payday Loan, and Not Specified': 0.002,
#   'Auto Loan, and Mortgage Loan': 0.002,
#   'Mortgage Loan, and Debt Consolidation Loan': 0.002,
#   'Payday Loan, and Credit-Builder Loan': 0.002,
#   'Debt Consolidation Loan, and Not Specified': 0.00192,
#   'Payday Loan, and Mortgage Loan': 0.00192,
#   'Not Specified, and Mortgage Loan': 0.00192,
#   'Personal Loan, and Home Equity Loan': 0.00192,
#   'Student Loan, and Mortgage Loan': 0.00192,
#   'Home Equity Loan, and Credit-Builder Loan': 0.00192,
#   'Payday Loan, and Payday Loan': 0.00184,
#   'Personal Loan, and Mortgage Loan': 0.00184,
#   'Home Equity Loan, and Home Equity Loan': 0.00184,
#   'Auto Loan, and Home Equity Loan': 0.00184,
#   'Personal Loan, and Payday Loan': 0.00184,
#   'Mortgage Loan, and Credit-Builder Loan': 0.00184,
#   'Auto Loan, and Credit-Builder Loan': 0.00176,
#   'Student Loan, and Personal Loan': 0.00176,
#   'Personal Loan, and Personal Loan': 0.00176,
#   'Mortgage Loan, and Personal Loan': 0.00176,
#   'Not Specified, and Home Equity Loan': 0.00168,
#   'Debt Consolidation Loan, and Mortgage Loan': 0.00168,
#   'Auto Loan, and Not Specified': 0.00168,
#   'Credit-Builder Loan, and Payday Loan': 0.00168,
#   'Credit-Builder Loan, and Personal Loan': 0.00168,
#   'Student Loan, and Home Equity Loan': 0.00168,
#   'Payday Loan, and Home Equity Loan': 0.00168,
#   'Mortgage Loan, and Payday Loan': 0.00168,
#   'Credit-Builder Loan, and Student Loan': 0.00168,
#   'Auto Loan, and Student Loan': 0.0016,
#   'Credit-Builder Loan, and Credit-Builder Loan': 0.0016,
#   'Student Loan, and Not Specified': 0.0016,
#   'Debt Consolidation Loan, and Credit-Builder Loan': 0.0016,
#   'Student Loan, and Debt Consolidation Loan': 0.00152,
#   'Debt Consolidation Loan, and Auto Loan': 0.00152,
#   'Mortgage Loan, and Auto Loan': 0.00152,
#   'Home Equity Loan, and Payday Loan': 0.00152,
#   'Debt Consolidation Loan, and Personal Loan': 0.00152,
#   'Home Equity Loan, and Auto Loan': 0.00152,
#   'Auto Loan, and Auto Loan': 0.00152,
#   'Not Specified, and Not Specified': 0.00144,
#   'Not Specified, and Personal Loan': 0.00144,
#   'Personal Loan, and Auto Loan': 0.00136,
#   'Home Equity Loan, and Personal Loan': 0.00136,
#   'Debt Consolidation Loan, and Student Loan': 0.00136,
#   'Not Specified, and Student Loan': 0.0012,
#   'Student Loan, Not Specified, and Student Loan': 0.00064,
#   'Debt Consolidation Loan, Mortgage Loan, and Home Equity Loan': 0.00064,
#   'Auto Loan, Payday Loan, and Personal Loan': 0.00064,
#   'Mortgage Loan, Student Loan, and Student Loan': 0.00064,
#   'Credit-Builder Loan, Not Specified, and Mortgage Loan': 0.00056,
#   'Not Specified, Debt Consolidation Loan, and Not Specified': 0.00056,
#   'Not Specified, Home Equity Loan, and Home Equity Loan': 0.00056,
#   'Student Loan, Mortgage Loan, and Not Specified': 0.00056,
#   'Credit-Builder Loan, Credit-Builder Loan, and Auto Loan': 0.00056,
#   'Mortgage Loan, Personal Loan, and Not Specified': 0.00056,
#   'Personal Loan, Mortgage Loan, and Payday Loan': 0.00056,
#   'Mortgage Loan, Not Specified, and Debt Consolidation Loan': 0.00056,
#   'Credit-Builder Loan, Not Specified, and Debt Consolidation Loan': 0.00056,
#   'Personal Loan, Credit-Builder Loan, and Debt Consolidation Loan': 0.00048,
#   'Payday Loan, Student Loan, and Not Specified': 0.00048,
#   'Personal Loan, Home Equity Loan, and Mortgage Loan': 0.00048,
#   'Student Loan, Auto Loan, and Mortgage Loan': 0.00048,
#   'Credit-Builder Loan, Home Equity Loan, and Credit-Builder Loan': 0.00048,
#   'Home Equity Loan, Student Loan, and Student Loan': 0.00048,
#   'Auto Loan, Not Specified, and Mortgage Loan': 0.00048,
#   'Credit-Builder Loan, Personal Loan, and Mortgage Loan': 0.00048,
#   'Personal Loan, Personal Loan, and Payday Loan': 0.00048,
#   'Debt Consolidation Loan, Credit-Builder Loan, and Student Loan': 0.00048,
#   'Credit-Builder Loan, Debt Consolidation Loan, and Student Loan': 0.00048,
#   'Not Specified, Not Specified, and Auto Loan': 0.00048,
#   'Auto Loan, Payday Loan, and Debt Consolidation Loan': 0.00048,
#   'Auto Loan, Student Loan, and Payday Loan': 0.00048,
#   'Payday Loan, Home Equity Loan, and Debt Consolidation Loan': 0.00048,
#   'Personal Loan, Debt Consolidation Loan, and Mortgage Loan': 0.00048,
#   'Student Loan, Auto Loan, and Personal Loan': 0.00048,
#   'Debt Consolidation Loan, Debt Consolidation Loan, and Personal Loan': 0.00048,
#   'Student Loan, Mortgage Loan, and Debt Consolidation Loan': 0.00048,
#   'Debt Consolidation Loan, Auto Loan, and Payday Loan': 0.00048,
#   'Debt Consolidation Loan, Not Specified, and Home Equity Loan': 0.00048,
#   'Not Specified, Mortgage Loan, and Debt Consolidation Loan': 0.00048,
#   'Debt Consolidation Loan, Student Loan, and Debt Consolidation Loan': 0.00048,
#   'Payday Loan, Payday Loan, and Home Equity Loan': 0.00048,
#   'Credit-Builder Loan, Debt Consolidation Loan, and Payday Loan': 0.00048,
#   'Not Specified, Not Specified, and Student Loan': 0.00048,
#   'Personal Loan, Student Loan, and Student Loan': 0.00048,
#   'Home Equity Loan, Auto Loan, and Not Specified': 0.00048,
#   'Mortgage Loan, Personal Loan, and Payday Loan': 0.0004,
#   'Debt Consolidation Loan, Credit-Builder Loan, and Home Equity Loan': 0.0004,
#   'Not Specified, Not Specified, and Debt Consolidation Loan': 0.0004,
#   'Credit-Builder Loan, Credit-Builder Loan, and Mortgage Loan': 0.0004,
#   'Mortgage Loan, Student Loan, and Debt Consolidation Loan': 0.0004,
#   'Auto Loan, Home Equity Loan, and Personal Loan': 0.0004,
#   'Payday Loan, Debt Consolidation Loan, and Student Loan': 0.0004,
#   'Personal Loan, Personal Loan, and Home Equity Loan': 0.0004,
#   'Debt Consolidation Loan, Home Equity Loan, and Student Loan': 0.0004,
#   'Home Equity Loan, Credit-Builder Loan, and Debt Consolidation Loan': 0.0004,
#   'Credit-Builder Loan, Home Equity Loan, and Student Loan': 0.0004,
#   'Credit-Builder Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.0004,
#   'Not Specified, Home Equity Loan, and Student Loan': 0.0004,
#   'Home Equity Loan, Payday Loan, and Not Specified': 0.0004,
#   'Credit-Builder Loan, Not Specified, and Credit-Builder Loan': 0.0004,
#   'Payday Loan, Credit-Builder Loan, and Auto Loan': 0.0004,
#   'Debt Consolidation Loan, Not Specified, and Debt Consolidation Loan': 0.0004,
#   'Student Loan, Mortgage Loan, and Student Loan': 0.0004,
#   'Home Equity Loan, Payday Loan, and Personal Loan': 0.0004,
#   'Debt Consolidation Loan, Auto Loan, and Personal Loan': 0.0004,
#   'Home Equity Loan, Not Specified, and Debt Consolidation Loan': 0.0004,
#   'Student Loan, Not Specified, and Payday Loan': 0.0004,
#   'Credit-Builder Loan, Mortgage Loan, and Credit-Builder Loan': 0.0004,
#   'Payday Loan, Personal Loan, and Student Loan': 0.0004,
#   'Debt Consolidation Loan, Personal Loan, and Mortgage Loan': 0.0004,
#   'Payday Loan, Payday Loan, and Not Specified': 0.0004,
#   'Not Specified, Debt Consolidation Loan, and Auto Loan': 0.0004,
#   'Auto Loan, Auto Loan, and Not Specified': 0.0004,
#   'Payday Loan, Personal Loan, and Credit-Builder Loan': 0.0004,
#   'Credit-Builder Loan, Mortgage Loan, and Payday Loan': 0.0004,
#   'Personal Loan, Auto Loan, and Credit-Builder Loan': 0.0004,
#   'Debt Consolidation Loan, Debt Consolidation Loan, and Home Equity Loan': 0.0004,
#   'Personal Loan, Auto Loan, and Not Specified': 0.0004,
#   'Credit-Builder Loan, Home Equity Loan, and Not Specified': 0.0004,
#   'Payday Loan, Credit-Builder Loan, and Mortgage Loan': 0.0004,
#   'Student Loan, Debt Consolidation Loan, and Personal Loan': 0.0004,
#   'Credit-Builder Loan, Home Equity Loan, and Payday Loan': 0.0004,
#   'Home Equity Loan, Debt Consolidation Loan, and Mortgage Loan': 0.0004,
#   'Personal Loan, Personal Loan, and Personal Loan': 0.0004,
#   'Personal Loan, Auto Loan, and Student Loan': 0.0004,
#   'Debt Consolidation Loan, Home Equity Loan, and Not Specified': 0.0004,
#   'Home Equity Loan, Home Equity Loan, and Debt Consolidation Loan': 0.0004,
#   'Auto Loan, Auto Loan, and Home Equity Loan': 0.0004,
#   'Home Equity Loan, Auto Loan, and Home Equity Loan': 0.0004,
#   'Mortgage Loan, Payday Loan, and Mortgage Loan': 0.0004,
#   'Payday Loan, Not Specified, and Mortgage Loan': 0.0004,
#   'Credit-Builder Loan, Credit-Builder Loan, and Not Specified': 0.0004,
#   'Auto Loan, Personal Loan, and Payday Loan': 0.0004,
#   'Debt Consolidation Loan, Student Loan, and Auto Loan': 0.0004,
#   'Personal Loan, Mortgage Loan, and Personal Loan': 0.0004,
#   'Not Specified, Debt Consolidation Loan, and Home Equity Loan': 0.0004,
#   'Home Equity Loan, Home Equity Loan, and Auto Loan': 0.0004,
#   'Credit-Builder Loan, Auto Loan, and Home Equity Loan': 0.0004,
#   'Student Loan, Mortgage Loan, and Home Equity Loan': 0.0004,
#   'Auto Loan, Debt Consolidation Loan, and Payday Loan': 0.0004,
#   'Home Equity Loan, Auto Loan, and Debt Consolidation Loan': 0.00032,
#   'Not Specified, Credit-Builder Loan, and Not Specified': 0.00032,
#   'Not Specified, Student Loan, and Home Equity Loan': 0.00032,
#   'Mortgage Loan, Personal Loan, and Mortgage Loan': 0.00032,
#   'Home Equity Loan, Mortgage Loan, and Home Equity Loan': 0.00032,
#   'Student Loan, Credit-Builder Loan, and Debt Consolidation Loan': 0.00032,
#   'Personal Loan, Auto Loan, and Debt Consolidation Loan': 0.00032,
#   'Debt Consolidation Loan, Personal Loan, and Personal Loan': 0.00032,
#   'Payday Loan, Credit-Builder Loan, and Student Loan': 0.00032,
#   'Payday Loan, Home Equity Loan, and Payday Loan': 0.00032,
#   'Debt Consolidation Loan, Not Specified, and Mortgage Loan': 0.00032,
#   'Home Equity Loan, Student Loan, and Credit-Builder Loan': 0.00032,
#   'Payday Loan, Personal Loan, and Not Specified': 0.00032,
#   'Student Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00032,
#   'Auto Loan, Home Equity Loan, and Not Specified': 0.00032,
#   'Not Specified, Payday Loan, and Payday Loan': 0.00032,
#   'Auto Loan, Not Specified, and Debt Consolidation Loan': 0.00032,
#   'Personal Loan, Mortgage Loan, and Home Equity Loan': 0.00032,
#   'Payday Loan, Debt Consolidation Loan, and Auto Loan': 0.00032,
#   'Mortgage Loan, Home Equity Loan, and Mortgage Loan': 0.00032,
#   'Personal Loan, Payday Loan, and Mortgage Loan': 0.00032,
#   'Payday Loan, Student Loan, and Debt Consolidation Loan': 0.00032,
#   'Not Specified, Payday Loan, and Not Specified': 0.00032,
#   'Mortgage Loan, Auto Loan, and Personal Loan': 0.00032,
#   'Debt Consolidation Loan, Auto Loan, and Home Equity Loan': 0.00032,
#   'Auto Loan, Auto Loan, and Personal Loan': 0.00032,
#   'Mortgage Loan, Home Equity Loan, and Debt Consolidation Loan': 0.00032,
#   'Payday Loan, Payday Loan, and Debt Consolidation Loan': 0.00032,
#   'Student Loan, Personal Loan, and Home Equity Loan': 0.00032,
#   'Mortgage Loan, Payday Loan, and Not Specified': 0.00032,
#   'Credit-Builder Loan, Mortgage Loan, and Student Loan': 0.00032,
#   'Student Loan, Home Equity Loan, and Student Loan': 0.00032,
#   'Not Specified, Student Loan, and Payday Loan': 0.00032,
#   'Not Specified, Mortgage Loan, and Credit-Builder Loan': 0.00032,
#   'Student Loan, Home Equity Loan, and Payday Loan': 0.00032,
#   'Payday Loan, Payday Loan, and Auto Loan': 0.00032,
#   'Student Loan, Auto Loan, and Not Specified': 0.00032,
#   'Not Specified, Payday Loan, and Student Loan': 0.00032,
#   'Auto Loan, Mortgage Loan, and Student Loan': 0.00032,
#   'Debt Consolidation Loan, Student Loan, and Mortgage Loan': 0.00032,
#   'Student Loan, Student Loan, and Home Equity Loan': 0.00032,
#   'Credit-Builder Loan, Home Equity Loan, and Auto Loan': 0.00032,
#   'Auto Loan, Credit-Builder Loan, and Auto Loan': 0.00032,
#   'Payday Loan, Student Loan, and Payday Loan': 0.00032,
#   'Auto Loan, Student Loan, and Auto Loan': 0.00032,
#   'Debt Consolidation Loan, Not Specified, and Auto Loan': 0.00032,
#   'Not Specified, Debt Consolidation Loan, and Personal Loan': 0.00032,
#   'Mortgage Loan, Home Equity Loan, and Student Loan': 0.00032,
#   'Personal Loan, Payday Loan, and Debt Consolidation Loan': 0.00032,
#   'Payday Loan, Not Specified, and Personal Loan': 0.00032,
#   'Payday Loan, Not Specified, and Debt Consolidation Loan': 0.00032,
#   'Mortgage Loan, Credit-Builder Loan, and Home Equity Loan': 0.00032,
#   'Personal Loan, Auto Loan, and Mortgage Loan': 0.00032,
#   'Not Specified, Student Loan, and Mortgage Loan': 0.00032,
#   'Student Loan, Payday Loan, and Debt Consolidation Loan': 0.00032,
#   'Debt Consolidation Loan, Personal Loan, and Not Specified': 0.00032,
#   'Student Loan, Credit-Builder Loan, and Mortgage Loan': 0.00032,
#   'Debt Consolidation Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00032,
#   'Mortgage Loan, Student Loan, and Not Specified': 0.00032,
#   'Credit-Builder Loan, Not Specified, and Not Specified': 0.00032,
#   'Not Specified, Mortgage Loan, and Auto Loan': 0.00032,
#   'Not Specified, Personal Loan, and Student Loan': 0.00032,
#   'Mortgage Loan, Home Equity Loan, and Auto Loan': 0.00032,
#   'Home Equity Loan, Personal Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00032,
#   'Auto Loan, Home Equity Loan, and Student Loan': 0.00032,
#   'Mortgage Loan, Student Loan, and Payday Loan': 0.00032,
#   'Home Equity Loan, Auto Loan, and Auto Loan': 0.00032,
#   'Debt Consolidation Loan, Personal Loan, and Home Equity Loan': 0.00032,
#   'Mortgage Loan, Student Loan, and Mortgage Loan': 0.00032,
#   'Home Equity Loan, Payday Loan, and Credit-Builder Loan': 0.00032,
#   'Personal Loan, Payday Loan, and Student Loan': 0.00032,
#   'Student Loan, Personal Loan, and Mortgage Loan': 0.00032,
#   'Credit-Builder Loan, Debt Consolidation Loan, and Not Specified': 0.00032,
#   'Home Equity Loan, Student Loan, and Home Equity Loan': 0.00032,
#   'Home Equity Loan, Personal Loan, and Auto Loan': 0.00032,
#   'Mortgage Loan, Debt Consolidation Loan, and Home Equity Loan': 0.00032,
#   'Auto Loan, Student Loan, and Student Loan': 0.00032,
#   'Payday Loan, Home Equity Loan, and Mortgage Loan': 0.00032,
#   'Mortgage Loan, Auto Loan, and Auto Loan': 0.00032,
#   'Mortgage Loan, Personal Loan, and Debt Consolidation Loan': 0.00032,
#   'Debt Consolidation Loan, Mortgage Loan, and Auto Loan': 0.00032,
#   'Auto Loan, Payday Loan, and Payday Loan': 0.00032,
#   'Personal Loan, Debt Consolidation Loan, and Payday Loan': 0.00032,
#   'Debt Consolidation Loan, Debt Consolidation Loan, and Credit-Builder Loan': 0.00032,
#   'Credit-Builder Loan, Personal Loan, and Personal Loan': 0.00032,
#   'Personal Loan, Not Specified, and Payday Loan': 0.00032,
#   'Mortgage Loan, Auto Loan, and Home Equity Loan': 0.00032,
#   'Personal Loan, Student Loan, and Personal Loan': 0.00032,
#   'Payday Loan, Personal Loan, and Payday Loan': 0.00032,
#   'Personal Loan, Payday Loan, and Home Equity Loan': 0.00032,
#   'Personal Loan, Student Loan, and Mortgage Loan': 0.00032,
#   'Student Loan, Not Specified, and Personal Loan': 0.00032,
#   'Not Specified, Student Loan, and Student Loan': 0.00032,
#   'Mortgage Loan, Personal Loan, and Student Loan': 0.00032,
#   'Payday Loan, Debt Consolidation Loan, and Mortgage Loan': 0.00032,
#   'Not Specified, Auto Loan, and Credit-Builder Loan': 0.00032,
#   'Home Equity Loan, Credit-Builder Loan, and Home Equity Loan': 0.00032,
#   'Personal Loan, Debt Consolidation Loan, and Auto Loan': 0.00032,
#   'Payday Loan, Not Specified, and Not Specified': 0.00032,
#   'Student Loan, Debt Consolidation Loan, and Mortgage Loan': 0.00032,
#   'Home Equity Loan, Mortgage Loan, and Student Loan': 0.00032,
#   'Auto Loan, Home Equity Loan, and Payday Loan': 0.00032,
#   'Mortgage Loan, Payday Loan, and Home Equity Loan': 0.00032,
#   'Credit-Builder Loan, Student Loan, and Payday Loan': 0.00032,
#   'Credit-Builder Loan, Payday Loan, and Student Loan': 0.00032,
#   'Payday Loan, Debt Consolidation Loan, and Payday Loan': 0.00032,
#   'Auto Loan, Credit-Builder Loan, and Not Specified': 0.00032,
#   'Auto Loan, Debt Consolidation Loan, and Home Equity Loan': 0.00024,
#   'Personal Loan, Not Specified, and Not Specified': 0.00024,
#   'Not Specified, Personal Loan, and Not Specified': 0.00024,
#   'Mortgage Loan, Debt Consolidation Loan, and Debt Consolidation Loan': 0.00024,
#   'Auto Loan, Personal Loan, and Home Equity Loan': 0.00024,
#   'Mortgage Loan, Not Specified, Credit-Builder Loan, and Student Loan': 0.00024,
#   'Credit-Builder Loan, Not Specified, Debt Consolidation Loan, and Student Loan': 0.00024,
#   'Payday Loan, Home Equity Loan, and Not Specified': 0.00024,
#   'Auto Loan, Mortgage Loan, and Not Specified': 0.00024,
#   'Credit-Builder Loan, Payday Loan, and Not Specified': 0.00024,
#   'Payday Loan, Debt Consolidation Loan, and Debt Consolidation Loan': 0.
loan, Debt Consolidation Loan, and Debt Consolidation Loan': 0.00024,
#   'Personal Loan, Student Loan, and Home Equity Loan': 0.00024,
#   'Credit-Builder Loan, Debt Consolidation Loan, Home Equity Loan, and Credit-Builder Loan': 0.00024,
#   'Payday Loan, Payday Loan, Auto Loan, and Home Equity Loan': 0.00024,
#   'Not Specified, Mortgage Loan, and Student Loan': 0.00024,
#   'Student Loan, Home Equity Loan, Payday Loan, and Debt Consolidation Loan': 0.00024,
#   'Personal Loan, Home Equity Loan, and Personal Loan': 0.00024,
#   'Auto Loan, Mortgage Loan, and Auto Loan': 0.00024,
#   'Mortgage Loan, Payday Loan, and Debt Consolidation Loan': 0.00024,
#   'Payday Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00024,
#   'Not Specified, Debt Consolidation Loan, and Debt Consolidation Loan': 0.00024,
#   'Auto Loan, Not Specified, and Auto Loan': 0.00024,
#   'Payday Loan, Student Loan, and Credit-Builder Loan': 0.00024,
#   'Not Specified, Home Equity Loan, and Auto Loan': 0.00024,
#   'Credit-Builder Loan, Student Loan, and Mortgage Loan': 0.00024,
#   'Credit-Builder Loan, Payday Loan, and Credit-Builder Loan': 0.00024,
#   'Mortgage Loan, Personal Loan, Payday Loan, and Debt Consolidation Loan': 0.00024,
#   'Not Specified, Personal Loan, and Mortgage Loan': 0.00024,
#   'Not Specified, Personal Loan, and Home Equity Loan': 0.00024,
#   'Debt Consolidation Loan, Debt Consolidation Loan, and Auto Loan': 0.00024,
#   'Auto Loan, Auto Loan, Auto Loan, and Home Equity Loan': 0.00024,
#   'Mortgage Loan, Home Equity Loan, and Personal Loan': 0.00024,
#   'Not Specified, Payday Loan, and Auto Loan': 0.00024,
#   'Student Loan, Debt Consolidation Loan, and Debt Consolidation Loan': 0.00024,
#   'Auto Loan, Home Equity Loan, and Home Equity Loan': 0.00024,
#   'Credit-Builder Loan, Not Specified, Not Specified, and Auto Loan': 0.00024,
#   'Mortgage Loan, Payday Loan, and Student Loan': 0.00024,
#   'Personal Loan, Personal Loan, and Mortgage Loan': 0.00024,
#   'Home Equity Loan, Home Equity Loan, and Personal Loan': 0.00024,
#   'Home Equity Loan, Personal Loan, and Not Specified': 0.00024,
#   'Debt Consolidation Loan, Payday Loan, and Mortgage Loan': 0.00024,
#   'Personal Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00024,
#   'Home Equity Loan, Auto Loan, and Mortgage Loan': 0.00024,
#   'Credit-Builder Loan, Debt Consolidation Loan, and Auto Loan': 0.00024,
#   'Auto Loan, Not Specified, and Payday Loan': 0.00024,
#   'Not Specified, Debt Consolidation Loan, and Student Loan': 0.00024,
#   'Home Equity Loan, Debt Consolidation Loan, and Auto Loan': 0.00024,
#   'Payday Loan, Auto Loan, and Home Equity Loan': 0.00024,
#   'Personal Loan, Home Equity Loan, and Payday Loan': 0.00024,
#   'Mortgage Loan, Student Loan, and Credit-Builder Loan': 0.00024,
#   'Credit-Builder Loan, Student Loan, and Student Loan': 0.00024,
#   'Auto Loan, Credit-Builder Loan, and Debt Consolidation Loan': 0.00024,
#   'Personal Loan, Mortgage Loan, and Debt Consolidation Loan': 0.00024,
#   'Not Specified, Not Specified, and Credit-Builder Loan': 0.00024,
#   'Home Equity Loan, Home Equity Loan, and Payday Loan': 0.00024,
#   'Credit-Builder Loan, Personal Loan, and Student Loan': 0.00024,
#   'Mortgage Loan, Payday Loan, and Credit-Builder Loan': 0.00024,
#   'Not Specified, Personal Loan, and Personal Loan': 0.00024,
#   'Auto Loan, Personal Loan, and Not Specified': 0.00024,
#   'Debt Consolidation Loan, Personal Loan, and Payday Loan': 0.00024,
#   'Mortgage Loan, Home Equity Loan, and Credit-Builder Loan': 0.00024,
#   'Payday Loan, Student Loan, and Auto Loan': 0.00024,
#   'Student Loan, Debt Consolidation Loan, and Auto Loan': 0.00024,
#   'Debt Consolidation Loan, Auto Loan, and Not Specified': 0.00024,
#   'Not Specified, Auto Loan, Mortgage Loan, and Debt Consolidation Loan': 0.00024,
#   'Debt Consolidation Loan, Home Equity Loan, and Mortgage Loan': 0.00024,
#   'Auto Loan, Not Specified, and Not Specified': 0.00024,
#   'Not Specified, Auto Loan, and Auto Loan': 0.00024,
#   'Personal Loan, Credit-Builder Loan, and Mortgage Loan': 0.00024,
#   'Credit-Builder Loan, Auto Loan, and Mortgage Loan': 0.00024,
#   'Student Loan, Payday Loan, and Personal Loan': 0.00024,
#   'Not Specified, Not Specified, Home Equity Loan, and Student Loan': 0.00024,
#   'Credit-Builder Loan, Not Specified, and Auto Loan': 0.00024,
#   'Credit-Builder Loan, Mortgage Loan, and Debt Consolidation Loan': 0.00024,
#   'Credit-Builder Loan, Student Loan, and Credit-Builder Loan': 0.00024,
#   'Credit-Builder Loan, Home Equity Loan, and Mortgage Loan': 0.00024,
#   'Student Loan, Home Equity Loan, Personal Loan, and Credit-Builder Loan': 0.00024,
#   'Debt Consolidation Loan, Student Loan, and Home Equity Loan': 0.00024,
#   'Debt Consolidation Loan, Student Loan, and Student Loan': 0.00024,
#   'Not Specified, Credit-Builder Loan, and Mortgage Loan': 0.00024,
#   'Debt Consolidation Loan, Auto Loan, and Mortgage Loan': 0.00024,
#   'Home Equity Loan, Student Loan, and Debt Consolidation Loan': 0.00024,
#   'Debt Consolidation Loan, Home Equity Loan, and Payday Loan': 0.00024,
#   'Not Specified, Mortgage Loan, and Not Specified': 0.00024,
#   'Home Equity Loan, Mortgage Loan, Payday Loan, and Home Equity Loan': 0.00024,
#   'Home Equity Loan, Not Specified, and Student Loan': 0.00024,
#   'Auto Loan, Mortgage Loan, and Mortgage Loan': 0.00024,
#   'Personal Loan, Personal Loan, and Debt Consolidation Loan': 0.00024,
#   'Personal Loan, Student Loan, and Not Specified': 0.00024,
#   'Auto Loan, Debt Consolidation Loan, and Credit-Builder Loan': 0.00024,
#   'Not Specified, Auto Loan, and Mortgage Loan': 0.00024,
#   'Home Equity Loan, Credit-Builder Loan, and Student Loan': 0.00024,
#   'Student Loan, Home Equity Loan, and Auto Loan': 0.00024,
#   'Not Specified, Not Specified, and Home Equity Loan': 0.00024,
#   'Credit-Builder Loan, Student Loan, Student Loan, and Credit-Builder Loan': 0.00024,
#   'Student Loan, Mortgage Loan, and Personal Loan': 0.00024,
#   'Payday Loan, Not Specified, and Student Loan': 0.00024,
#   'Auto Loan, Home Equity Loan, Not Specified, and Personal Loan': 0.00024,
#   'Credit-Builder Loan, Student Loan, and Not Specified': 0.00024,
#   'Not Specified, Student Loan, and Personal Loan': 0.00024,
#   'Credit-Builder Loan, Home Equity Loan, and Personal Loan': 0.00024,
#   'Payday Loan, Auto Loan, and Personal Loan': 0.00024,
#   'Auto Loan, Personal Loan, and Mortgage Loan': 0.00024,
#   'Home Equity Loan, Home Equity Loan, and Student Loan': 0.00024,
#   'Auto Loan, Auto Loan, and Auto Loan': 0.00024,
#   'Student Loan, Home Equity Loan, and Mortgage Loan': 0.00024,
#   'Payday Loan, Payday Loan, and Student Loan': 0.00024,
#   'Not Specified, Payday Loan, and Mortgage Loan': 0.00024,
#   'Student Loan, Payday Loan, and Payday Loan': 0.00024,
#   'Auto Loan, Home Equity Loan, and Credit-Builder Loan': 0.00024,
#   'Home Equity Loan, Auto Loan, and Student Loan': 0.00024,
#   'Student Loan, Student Loan, and Auto Loan': 0.00024,
#   'Personal Loan, Auto Loan, and Auto Loan': 0.00024,
#   'Not Specified, Auto Loan, and Debt Consolidation Loan': 0.00016,
#   'Debt Consolidation Loan, Student Loan, and Credit-Builder Loan': 0.00016,
#   'Personal Loan, Personal Loan, Not Specified, and Personal Loan': 0.00016,
#   'Student Loan, Auto Loan, Auto Loan, and Student Loan': 0.00016,
#   'Mortgage Loan, Student Loan, and Personal Loan': 0.00016,
#   'Student Loan, Student Loan, Not Specified, and Payday Loan': 0.00016,
#   'Not Specified, Not Specified, Auto Loan, and Credit-Builder Loan': 0.00016,
#   'Mortgage Loan, Debt Consolidation Loan, and Personal Loan': 0.00016,
#   'Home Equity Loan, Not Specified, Not Specified, and Student Loan': 0.00016,
#   'Credit-Builder Loan, Mortgage Loan, and Personal Loan': 0.00016,
#   'Not Specified, Home Equity Loan, Mortgage Loan, Debt Consolidation Loan, and Student Loan': 0.00016,
#   'Mortgage Loan, Home Equity Loan, Not Specified, and Mortgage Loan': 0.00016,
#   'Home Equity Loan, Payday Loan, Payday Loan, and Personal Loan': 0.00016,
#   'Debt Consolidation Loan, Credit-Builder Loan, Payday Loan, and Auto Loan': 0.00016,
#   'Home Equity Loan, Credit-Builder Loan, and Not Specified': 0.00016,
#   'Credit-Builder Loan, Payday Loan, Credit-Builder Loan, and Payday Loan': 0.00016,
#   'Mortgage Loan, Auto Loan, and Mortgage Loan': 0.00016,
#   'Not Specified, Auto Loan, and Not Specified': 0.00016,
#   'Debt Consolidation Loan, Debt Consolidation Loan, Mortgage Loan, and Payday Loan': 0.00016,
#   'Home Equity Loan, Mortgage Loan, Home Equity Loan, and Debt Consolidation Loan': 0.00016,
#   'Personal Loan, Student Loan, and Credit-Builder Loan': 0.00016,
#   'Personal Loan, Mortgage Loan, Payday Loan, and Personal Loan': 0.00016,
#   'Payday Loan, Student Loan, Not Specified, and Personal Loan': 0.00016,
#   'Auto Loan, Mortgage Loan, Student Loan, and Not Specified': 0.00016,
#   'Home Equity Loan, Home Equity Loan, Personal Loan, and Auto Loan': 0.00016,
#   'Mortgage Loan, Mortgage Loan, and Auto Loan': 0.00016,
#   'Student Loan, Student Loan, and Mortgage Loan': 0.00016,
#   'Credit-Builder Loan, Mortgage Loan, Home Equity Loan, and Mortgage Loan': 0.00016,
#   'Mortgage Loan, Payday Loan, Mortgage Loan, and Personal Loan': 0.00016,
#   'Payday Loan, Mortgage Loan, and Mortgage Loan': 0.00016,
#   'Credit-Builder Loan, Not Specified, Mortgage Loan, and Payday Loan': 0.00016,
#   'Personal Loan, Home Equity Loan, Auto Loan, and Debt Consolidation Loan': 0.00016,
#   'Credit-Builder Loan, Home Equity Loan, Not Specified, and Personal Loan': 0.00016,
#   'Payday Loan, Student Loan, and Home Equity Loan': 0.00016,
#   'Not Specified, Credit-Builder Loan, and Credit-Builder Loan': 0.00016,
#   'Personal Loan,
#   'Auto Loan, Debt Consolidation Loan, and Personal Loan': 0.00016,
#   'Auto Loan, Payday Loan, and Mortgage Loan': 0.00016,
#   'Personal Loan, Credit-Builder Loan, Credit-Builder Loan, and Home Equity Loan': 0.00016,
#   'Home Equity Loan, Debt Consolidation Loan, and Not Specified': 0.00016,
#   'Home Equity Loan, Payday Loan, and Mortgage Loan': 0.00016,
#   'Not Specified, Personal Loan, and Debt Consolidation Loan': 0.00016,
#   'Student Loan, Student Loan, Not Specified, and Not Specified': 0.00016,
#   'Credit-Builder Loan, Credit-Builder Loan, and Student Loan': 0.00016,
#   'Credit-Builder Loan, Home Equity Loan, Home Equity Loan, and Payday Loan': 0.00016,
#   'Payday Loan, Auto Loan, and Auto Loan': 0.00016,
#   'Mortgage Loan, Home Equity Loan, Payday Loan, and Mortgage Loan': 0.00016,
#   'Not Specified, Home Equity Loan, and Payday Loan': 0.00016,
#   'Mortgage Loan, Auto Loan, and Payday Loan': 0.00016,
#   'Personal Loan, Credit-Builder Loan, Payday Loan, and Payday Loan': 0.00016,
#   'Credit-Builder Loan, Debt Consolidation Loan, and Debt Consolidation Loan': 0.00016,
#   'Auto Loan, Personal Loan, Home Equity Loan, and Not Specified': 0.00016,
#   'Not Specified, Home Equity Loan, and Credit-Builder Loan': 0.00016,
#   'Student Loan, Credit-Builder Loan, Payday Loan, and Home Equity Loan': 0.00016,
#   'Payday Loan, Not Specified, Home Equity Loan, and Payday Loan': 0.00016,
#   'Auto Loan, Mortgage Loan, and Personal Loan': 0.00016,
#   'Mortgage Loan, Auto Loan, Personal Loan, and Student Loan': 0.00016,
#   'Debt Consolidation Loan, Student Loan, Credit-Builder Loan, and Home Equity Loan': 0.00016,
#   'Not Specified, Student Loan, Not Specified, and Credit-Builder Loan': 0.00016,
#   'Personal Loan, Home Equity Loan, Not Specified, and Credit-Builder Loan': 0.00016,
#   'Mortgage Loan, Mortgage Loan, Auto Loan, and Payday Loan': 0.00016,
#   'Mortgage Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00016,
#   'Payday Loan, Home Equity Loan, Payday Loan, and Auto Loan': 0.00016,
#   'Credit-Builder Loan, Credit-Builder Loan, Student Loan, and Credit-Builder Loan': 0.00016,
#   'Credit-Builder Loan, Auto Loan, Payday Loan, and Debt Consolidation Loan': 0.00016,
#   'Home Equity Loan, Credit-Builder Loan, and Payday Loan': 0.00016,
#   'Personal Loan, Payday Loan, and Not Specified': 0.00016,
#   'Credit-Builder Loan, Mortgage Loan, and Not Specified': 0.00016,
#   'Not Specified, Student Loan, Mortgage Loan, and Student Loan': 0.00016,
#   'Not Specified, Home Equity Loan, Auto Loan, and Credit-Builder Loan': 0.00016,
#   'Not Specified, Debt Consolidation Loan, Student Loan, and Credit-Builder Loan': 0.00016,
#   'Mortgage Loan, Home Equity Loan, and Not Specified': 0.00016,
#   'Credit-Builder Loan, Home Equity Loan, Not Specified, and Payday Loan': 0.00016,
#   'Payday Loan, Student Loan, Not Specified, and Home Equity Loan': 0.00016,
#   'Personal Loan, Auto Loan, and Payday Loan': 0.00016,
#   'Personal Loan, Payday Loan, and Payday Loan': 0.00016,
#   'Credit-Builder Loan, Student Loan, and Home Equity Loan': 0.00016,
#   'Payday Loan, Payday Loan, Payday Loan, and Debt Consolidation Loan': 0.00016,
#   'Student Loan, Not Specified, Student Loan, and Personal Loan': 0.00016,
#   'Credit-Builder Loan, Payday Loan, and Mortgage Loan': 0.00016,
#   'Student Loan, Debt Consolidation Loan, and Student Loan': 0.00016,
#   'Student Loan, Auto Loan, and Student Loan': 0.00016,
#   'Personal Loan, Home Equity Loan, and Auto Loan': 0.00016,
#   'Home Equity Loan, Payday Loan, and Debt Consolidation Loan': 0.00016,
#   'Student Loan, Student Loan, Home Equity Loan, and Not Specified': 0.00016,
#   'Payday Loan, Personal Loan, and Personal Loan': 0.00016,
#   'Home Equity Loan, Not Specified, and Payday Loan': 0.00016,
#   'Auto Loan, Debt Consolidation Loan, and Not Specified': 0.00016,
#   'Auto Loan, Auto Loan, and Student Loan': 0.00016,
#   'Payday Loan, Credit-Builder Loan, Credit-Builder Loan, and Payday Loan': 0.00016,
#   'Student Loan, Payday Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00016,
#   'Not Specified, Credit-Builder Loan, Student Loan, and Mortgage Loan': 0.00016,
#   'Credit-Builder Loan, Credit-Builder Loan, and Payday Loan': 0.00016,
#   'Payday Loan, Mortgage Loan, Payday Loan, and Not Specified': 0.00016,
#   'Debt Consolidation Loan, Debt Consolidation Loan, Personal Loan, and Mortgage Loan': 0.00016,
#   'Credit-Builder Loan, Not Specified, Student Loan, and Credit-Builder Loan': 0.00016,
#   'Not Specified, Mortgage Loan, and Payday Loan': 0.00016,
#   'Credit-Builder Loan, Auto Loan, Personal Loan, and Mortgage Loan': 0.00016,
#   'Home Equity Loan, Personal Loan, and Payday Loan': 0.00016,
#   'Credit-Builder Loan, Credit-Builder Loan, and Home Equity Loan': 0.00016,
#   'Not Specified, Home Equity Loan, Student Loan, and Credit-Builder Loan': 0.00016,
#   'Debt Consolidation Loan, Auto Loan, Not Specified, and Auto Loan': 0.00016,
#   'Not Specified, Debt Consolidation Loan, Payday Loan, and Debt Consolidation Loan': 0.00016,
#   'Debt Consolidation Loan, Mortgage Loan, Home Equity Loan, and Mortgage Loan': 0.00016,
#   'Home Equity Loan, Debt Consolidation Loan, Debt Consolidation Loan, and Credit-Builder Loan': 0.00016,
#   'Auto Loan, Payday Loan, and Credit-Builder Loan': 0.00016,
#   'Personal Loan, Student Loan, Home Equity Loan, and Payday Loan': 0.00016,
#   'Student Loan, Mortgage Loan, Auto Loan, and Student Loan': 0.00016,
#   'Credit-Builder Loan, Student Loan, Payday Loan, and Personal Loan': 0.00016,
#   'Personal Loan, Payday Loan, Credit-Builder Loan, and Credit-Builder Loan': 0.00016,
#   'Credit-Builder Loan, Not Specified, and Home Equity Loan': 0.00016,
#   'Personal Loan, Home Equity Loan, Not Specified, and Mortgage Loan': 0.00016,
#   'Student Loan, Not Specified, Home Equity Loan, and Not Specified': 0.00016,
#   'Mortgage Loan, Not Specified, Not Specified, and Home Equity Loan': 0.00016,
#   'Mortgage Loan, Credit-Builder Loan, and Payday Loan': 0.00016,
#   'Not Specified, Student Loan, and Credit-Builder Loan': 0.00016,
#   'Payday Loan, Mortgage Loan, Student Loan, and Auto Loan': 0.00016,
#   'Mortgage Loan, Auto Loan, Not Specified, and Not Specified': 0.00016,
#   'Not Specified, Auto Loan, and Home Equity Loan': 0.00016,
#   'Debt Consolidation Loan, Payday Loan, and Debt Consolidation Loan': 0.00016,
#   'Credit-Builder Loan, Credit-Builder Loan, Home Equity Loan, and Not Specified': 0.00016,
#   'Home Equity Loan, Home Equity Loan, and Mortgage Loan': 0.00016,
#   'Debt Consolidation Loan, Home Equity Loan, Home Equity Loan, and Student Loan': 0.00016,
#   'Payday Loan, Auto Loan, and Debt Consolidation Loan': 0.00016,
#   'Student Loan, Mortgage Loan, and Payday Loan': 0.00016,
#   'Mortgage Loan, Auto Loan, Debt Consolidation Loan, and Credit-Builder Loan': 0.
loan, and Credit-Builder Loan': 0.00016,
#   'Personal Loan, Debt Consolidation Loan, and Credit-Builder Loan': 0.00016,
#   'Debt Consolidation Loan, Home Equity Loan, and Auto Loan': 0.00016,
#   'Home Equity Loan, Not Specified, Not Specified, and Personal Loan': 0.00016,
#   'Student Loan, Debt Consolidation Loan, Auto Loan, and Auto Loan': 0.00016,
#   'Not Specified, Auto Loan, Home Equity Loan, and Debt Consolidation Loan': 0.00016,
#   'Credit-Builder Loan, Not Specified, Not Specified, and Personal Loan': 0.00016,
#   'Personal Loan, Personal Loan, Credit-Builder Loan, and Personal Loan': 0.00016,
#   'Mortgage Loan, Credit-Builder Loan, and Personal Loan': 0.00016,
#   'Debt Consolidation Loan, Mortgage Loan, and Personal Loan': 0.00016,
#   'Auto Loan, Payday Loan, and Not Specified': 0.00016,
#   'Student Loan, Debt Consolidation Loan, and Home Equity Loan': 0.00016,
#   'Payday Loan, Mortgage Loan, Debt Consolidation Loan, and Credit-Builder Loan': 0.00016,
#   'Home Equity Loan, Debt Consolidation Loan, and Personal Loan': 0.00016,
#   'Debt Consolidation Loan, Mortgage Loan, and Credit-Builder Loan': 0.00016,
#   'Personal Loan, Not Specified, Student Loan, and Mortgage Loan': 0.00016,
#   'Student Loan, Personal Loan, and Credit-Builder Loan': 0.00016,
#   'Credit-Builder Loan, Auto Loan, and Personal Loan': 0.00016,
#   'Auto Loan, Not Specified, Payday Loan, and Not Specified': 0.00016,
#   'Mortgage Loan, Mortgage Loan, and Not Specified': 0.00016,
# ...
#   'Debt Consolidation Loan, Home Equity Loan, Credit-Builder Loan, and Personal Loan': 0.00016,
#   'Student Loan, Auto Loan, Payday Loan, and Mortgage Loan': 0.00016,
#   'Auto Loan, Home Equity Loan, Not Specified, and Auto Loan': 0.00016,
#   'Student Loan, Home Equity Loan, Payday Loan, and Home Equity Loan': 0.00016,
#   'Home Equity Loan, Personal Loan, and Personal Loan': 0.00016,
#   'Student Loan, Debt Consolidation Loan, and Payday Loan': 0.00016,
#   'Home Equity Loan, Not Specified, Not Specified, and Not Specified': 0.00016,
#   'Not Specified, Auto Loan, and Student Loan': 0.00016,
#   'Credit-Builder Loan, Personal Loan, and Auto Loan': 0.00016,
#   'Credit-Builder Loan, Payday Loan, and Home Equity Loan': 0.00016,
#   'Home Equity Loan, Payday Loan, Auto Loan, and Auto Loan': 0.00016,
#   'Debt Consolidation Loan, Personal Loan, and Credit-Builder Loan': 0.00016,
#   'Payday Loan, Credit-Builder Loan, Auto Loan, and Personal Loan': 0.00016,
#   'Auto Loan, Debt Consolidation Loan, and Mortgage Loan': 0.00016,
#   'Personal Loan, Personal Loan, and Auto Loan': 0.00016,
#   'Payday Loan, Not Specified, and Auto Loan': 0.00016,
#   'Personal Loan, Payday Loan, Mortgage Loan, and Credit-Builder Loan': 0.00016,
#   'Student Loan, Not Specified, and Auto Loan': 0.00016,
#   'Auto Loan, Debt Consolidation Loan, Mortgage Loan, and Not Specified': 0.00016,
#   'Credit-Builder Loan, Student Loan, and Auto Loan': 0.00016,
#   'Personal Loan, Mortgage Loan, and Credit-Builder Loan': 0.00016,
#   'Auto Loan, Credit-Builder Loan, Auto Loan, and Auto Loan': 0.00016,
#   'Home Equity Loan, Auto Loan, Mortgage Loan, Auto Loan, Auto Loan, Personal Loan, Auto Loan, and Student Loan': 8e-05,
#   'Auto Loan, Mortgage Loan, Personal Loan, Credit-Builder Loan, Debt Consolidation Loan, Debt Consolidation Loan, Debt Consolidation Loan, Student Loan, and Credit-Builder Loan': 8e-05,
#   'Mortgage Loan, Home Equity Loan, Personal Loan, Home Equity Loan, Student Loan, Student Loan, Personal Loan, Debt Consolidation Loan, and Payday Loan': 8e-05,
#   'Auto Loan, Credit-Builder Loan, Home Equity Loan, and Credit-Builder Loan': 8e-05,
#   'Debt Consolidation Loan, Not Specified, Home Equity Loan, Auto Loan, Credit-Builder Loan, and Not Specified': 8e-05,
#   'Home Equity Loan, Debt Consolidation Loan, Personal Loan, Home Equity Loan, and Payday Loan': 8e-05,
#   'Credit-Builder Loan, Mortgage Loan, Student Loan, Student Loan, and Credit-Builder Loan': 8e-05,
#   'Home Equity Loan, Student Loan, Student Loan, Auto Loan, Payday Loan, Auto Loan, Not Specified, and Home Equity Loan': 8e-05,
#   'Student Loan, Credit-Builder Loan, Home Equity Loan, Auto Loan, Credit-Builder Loan, Personal Loan, and Auto Loan': 8e-05,
#   'Debt Consolidation Loan, Student Loan, Home Equity Loan, and Mortgage Loan': 8e-05,
#   'Payday Loan, Payday Loan, Payday Loan, and Student Loan': 8e-05,
#   'Auto Loan, Personal Loan, Personal Loan, and Student Loan': 8e-05,
#   'Not Specified, Home Equity Loan, Credit-Builder Loan, Debt Consolidation Loan, Student Loan, and Personal Loan': 8e-05,
#   'Mortgage Loan, Payday Loan, Not Specified, Home Equity Loan, and Student Loan': 8e-05,
#   'Payday Loan, Home Equity Loan, Personal Loan, Payday Loan, Credit-Builder Loan, Credit-Builder Loan, Not Specified, Credit-Builder Loan, and Not Specified': 8e-05,
#   'Payday Loan, Debt Consolidation Loan, Mortgage Loan, Debt Consolidation Loan, Auto Loan, Credit-Builder Loan, and Credit-Builder Loan': 8e-05,
#   ...},
#  'Credit_Mix': {'Standard': 0.36479,
#   'Good': 0.24337,
#   'Unknown_credit_mix': 0.20195,
#   'Bad': 0.18989},
#  'Payment_of_Min_Amount': {'Yes': 0.52326, 'No': 0.35667, 'NM': 0.12007},
#  'Payment_Behaviour': {'Low_spent_Small_value_payments': 0.25513,
#   'High_spent_Medium_value_payments': 0.1754,
#   'Low_spent_Medium_value_payments': 0.13861,
#   'High_spent_Large_value_payments': 0.13721,
#   'High_spent_Small_value_payments': 0.1134,
#   'Low_spent_Large_value_payments': 0.10425,
#   'Unknown_Payment_Behaviour': 0.076},
#  'Occupation': {'Lawyer': 0.07096,
#   'Engineer': 0.06864,
#   'Architect': 0.06824,
#   'Mechanic': 0.06776,
#   'Scientist': 0.06744,
#   'Accountant': 0.06744,
#   'Developer': 0.0672,
#   'Media_Manager': 0.0672,
#   'Teacher': 0.06672,
#   'Entrepreneur': 0.06648,
#   'Doctor': 0.06568,
#   'Journalist': 0.06536,
#   'Manager': 0.06432,
#   'Musician': 0.06352,
#   'Writer': 0.06304}}

# %% [markdown]
# ### Criação das bases de treino e teste (80:20)

# %%
#Criação das bases de treino e teste no formato 80:20

X_train, X_test, y_train, y_test = train_test_split(X_encoded,Y,test_size=0.2,random_state=42)

# %% [markdown]
# ### Teste com Modelo Random Forest (já possui feature selecion interno)

# %%
######FEATURE SELECTION E CRIAÇÃO DO MODELO RANDOM FOREST ############
forest=RandomForestClassifier()
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#Selecionando as features que foram usadas no Random forest (ESTE MODELO JA POSSUI UM FEATURE SELECTION INTERNO)
select = SelectFromModel(forest)
select.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
select.get_support()
# Out:
# array([False, False,  True, False, False, False, False, False, False,
#        False, False,  True, False, False,  True, False,  True,  True,
#         True,  True,  True, False,  True])

# %%
#Print das features utilizadas no modelo Random forest
features= X_train.columns[(select.get_support())]

print(features)
# Out:
# Index(['Credit_Mix', 'Interest_Rate', 'Delay_from_due_date',
#        'Changed_Credit_Limit', 'Outstanding_Debt', 'Credit_Utilization_Ratio',
#        'Amount_invested_monthly', 'Monthly_Balance',
#        'Credit_History_Age_Days'],
#       dtype='object')

# %%
y_pred_test = forest.predict(X_test)

# %% [markdown]
# #### Avaliação do Modelo Random Forest

# %%
# Score do modelo Random forest
accuracy_score(y_test, y_pred_test)
# Out:
# 0.80035

# %%
score_medio = cross_val_score(forest, X_train, y_train,
                            scoring='accuracy', cv=5)

print(score_medio.mean())
# Out:
# 0.7939

# %%
# Classificação das arvores criadas durante do Random Forest
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81      5874
#            1       0.82      0.81      0.81     10599
#            2       0.76      0.73      0.75      3527
#
#     accuracy                           0.80     20000
#    macro avg       0.79      0.79      0.79     20000
# weighted avg       0.80      0.80      0.80     20000

# %% [markdown]
# ### Teste com arvore de decisao classificatoria

# %% [markdown]
# #### Feature Selection

# %%
####Abordando o problema agora com Arvore classificatoria####
### Essa arvore tambem é robusta a outliers e escala #####

###Antes temos que fazer a melhor set de features para o modelo (antes em Random Forest, era selecionado automaticamente)###
### No caso vamos focar em achar fazer um classificador com melhor acuracia#####

###Feature selection###


##Para a arvore primeiramente fazer um feature selection usando o forward selection pela metrica de acuracia###


ar = DecisionTreeClassifier()

sfs1 = SFS(ar, 
           k_features=10, 
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='accuracy',
           cv=5)

sfs1 = sfs1.fit(X_train, y_train)
# Out:
# [2023-10-06 14:03:09] Features: 1/10 -- score: 0.7964249999999999
# [2023-10-06 14:03:39] Features: 2/10 -- score: 0.7971625
# [2023-10-06 14:04:17] Features: 3/10 -- score: 0.797375
# [2023-10-06 14:04:56] Features: 4/10 -- score: 0.7973874999999999
# [2023-10-06 14:05:36] Features: 5/10 -- score: 0.79745
# [2023-10-06 14:06:14] Features: 6/10 -- score: 0.7955125
# [2023-10-06 14:06:56] Features: 7/10 -- score: 0.793725
# [2023-10-06 14:07:45] Features: 8/10 -- score: 0.79065
# [2023-10-06 14:08:34] Features: 9/10 -- score: 0.785925
# [2023-10-06 14:09:28] Features: 10/10 -- score: 0.7831125

# %%
pd.DataFrame.from_dict(sfs1.get_metric_dict()).T
#As melhores features para esta arvore de decisao são
#'Type_of_Loan','Occupation','Monthly_Inhand_Salary','Outstanding_Debt'
# Out:
#                           feature_idx  \
# 1                                (7,)
# 2                             (7, 17)
# 3                          (5, 7, 17)
# 4                       (1, 5, 7, 17)
# 5                    (0, 1, 5, 7, 17)
# 6                 (0, 1, 5, 6, 7, 17)
# 7              (0, 1, 5, 6, 7, 8, 17)
# 8           (0, 1, 5, 6, 7, 8, 9, 17)
# 9       (0, 1, 5, 6, 7, 8, 9, 17, 22)
# 10  (0, 1, 5, 6, 7, 8, 9, 11, 17, 22)
#
#                                             cv_scores avg_score  \
# 1   [0.79725, 0.7950625, 0.7948125, 0.7980625, 0.7...  0.796425
# 2   [0.7980625, 0.7958125, 0.7958125, 0.7991875, 0...  0.797162
# 3   [0.798375, 0.7960625, 0.7963125, 0.799125, 0.797]  0.797375
# 4   [0.7984375, 0.79625, 0.79675, 0.7989375, 0.796...  0.797387
# 5             [0.7985, 0.79625, 0.7965, 0.799, 0.797]   0.79745
# 6   [0.796125, 0.7946875, 0.795125, 0.7981875, 0.7...  0.795512
# 7    [0.795125, 0.793, 0.7921875, 0.79575, 0.7925625]  0.793725
# 8   [0.7914375, 0.7899375, 0.788125, 0.794625, 0.7...   0.79065
# 9   [0.7879375, 0.787125, 0.78275, 0.7866875, 0.78...  0.785925
# 10  [0.7813125, 0.7851875, 0.780625, 0.786375, 0.7...  0.783112
#
#                                         feature_names  ci_bound   std_dev  \
# 1                            (Monthly_Inhand_Salary,)  0.001634  0.001271
# 2           (Monthly_Inhand_Salary, Outstanding_Debt)  0.001686  0.001312
# 3   (Occupation, Monthly_Inhand_Salary, Outstandin...  0.001527  0.001188
# 4   (Type_of_Loan, Occupation, Monthly_Inhand_Sala...  0.001395  0.001085
# 5   (Month, Type_of_Loan, Occupation, Monthly_Inha...  0.001414    0.0011
# 6   (Month, Type_of_Loan, Occupation, Age, Monthly...  0.002046  0.001592
# 7   (Month, Type_of_Loan, Occupation, Age, Monthly...  0.001845  0.001435
# 8   (Month, Type_of_Loan, Occupation, Age, Monthly...   0.00291  0.002264
# 9   (Month, Type_of_Loan, Occupation, Age, Monthly...  0.002355  0.001833
# 10  (Month, Type_of_Loan, Occupation, Age, Monthly...  0.002901  0.002257
#
#      std_err
# 1   0.000636
# 2   0.000656
# 3   0.000594
# 4   0.000542
# 5    0.00055
# 6   0.000796
# 7   0.000718
# 8   0.001132
# 9   0.000916
# 10  0.001129

# %% [markdown]
# #### Filtro da base de treino e teste para obter o set otimo de features

# %%
#Filtro da base de treino e teste para arvore de decisao
X_train_otimo =X_train[['Type_of_Loan','Occupation','Monthly_Inhand_Salary','Outstanding_Debt']]
X_test_otimo = X_test[['Type_of_Loan','Occupation','Monthly_Inhand_Salary','Outstanding_Debt']]

# %% [markdown]
# #### Criação do modelo de arvore de decisão classicatoria e avaliações

# %%
ar = DecisionTreeClassifier()
ar.fit(X_train_otimo,y_train)
y_pred_test_ar = ar.predict(X_test_otimo)

# %%
##Acuracia do Modelo de arvore
accuracy_score(y_test, y_pred_test_ar)
# Out:
# 0.80965

# %%
score_medio = cross_val_score(ar, X_train_otimo, y_train,
                            scoring='accuracy', cv=5)

print(score_medio.mean())
# Out:
# 0.7975625000000001

# %%
print(classification_report(y_test, y_pred_test_ar))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.83      5874
#            1       0.84      0.79      0.82     10599
#            2       0.77      0.76      0.76      3527
#
#     accuracy                           0.81     20000
#    macro avg       0.80      0.81      0.80     20000
# weighted avg       0.81      0.81      0.81     20000

# %% [markdown]
# ### Conclusão

# %% [markdown]
# #####  1 - Modelo de arvore configurado para o set ótimo de features opera com menos colunas: 9 - Random Forest e 4 - Arvore
# #####  2 - Modelo de arvore passa a precisao de random forest por muito pouco, já validado com validação cross com K=5 (Random = 0.794325 e Arvore =0.79746 )
# #####  3 - Modelo de arvore indiscutivelmente opera com MUITO menos processamento que random forest
#
#
# ##### Resultado : Pelo fato de consumir menos colunas e operar em menos tempo estaremos usando o modelo de arvore classificatoria para este exercicio como modelo de ML final para entrega.

# %% [markdown]
# # Exercício 2
#
# ##### Usar um algoritmo não supervisionado na base e falar da experiencia

# %%
#Criando Clusters por K-means

#Incialmente removes os outliers

# %%
data_all = pd.concat([X_encoded[['Type_of_Loan','Occupation','Monthly_Inhand_Salary','Outstanding_Debt']],Y],axis=1)

# %%
data_all['Credit_Score']=data_all['Credit_Score'].astype(float)

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Type_of_Loan           100000 non-null  float64
#  1   Occupation             100000 non-null  float64
#  2   Monthly_Inhand_Salary  100000 non-null  float64
#  3   Outstanding_Debt       100000 non-null  float64
#  4   Credit_Score           100000 non-null  float64
# dtypes: float64(5)
# memory usage: 3.8 MB

# %%
def remover_outliers_iqr(df):
    df_sem_outliers = df.copy()  
    Q1 = df_sem_outliers['Credit_Score'].quantile(0.25)
    Q3 = df_sem_outliers['Credit_Score'].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    df_sem_outliers = df_sem_outliers[(df_sem_outliers['Credit_Score'] >= limite_inferior) & (df_sem_outliers['Credit_Score'] <= limite_superior)]
    return df_sem_outliers

# Aplicar a função de remoção de outliers à coluna 'Credit_Score'
data_no_outliers = remover_outliers_iqr(data_all)

# %%
data_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Type_of_Loan           100000 non-null  float64
#  1   Occupation             100000 non-null  float64
#  2   Monthly_Inhand_Salary  100000 non-null  float64
#  3   Outstanding_Debt       100000 non-null  float64
#  4   Credit_Score           100000 non-null  float64
# dtypes: float64(5)
# memory usage: 4.6 MB

# %%
data_no_outliers.head()
# Out:
#    Type_of_Loan  Occupation  Monthly_Inhand_Salary  Outstanding_Debt  \
# 0       0.00008     0.06744            1824.843333            809.98
# 1       0.00008     0.06744            1824.843333            809.98
# 2       0.00008     0.06744            1824.843333            809.98
# 3       0.00008     0.06744            1824.843333            809.98
# 4       0.00008     0.06744            1824.843333            809.98
#
#    Credit_Score
# 0           2.0
# 1           2.0
# 2           2.0
# 3           2.0
# 4           2.0

# %%
###Deixando o dataset com a msm escala usando Min MAX escaler

scaler = MinMaxScaler()
data_escaled= scaler.fit_transform(data_no_outliers[['Type_of_Loan', 'Occupation', 'Monthly_Inhand_Salary','Outstanding_Debt']])
data_escaled = pd.DataFrame(data_escaled, columns=['Type_of_Loan', 'Occupation', 'Monthly_Inhand_Salary','Outstanding_Debt'])

# %%
data_for_kmeans = pd.concat([data_escaled, data_no_outliers['Credit_Score'].reset_index(drop=True)], axis=1)

# %%
colunas_kmeans = ['Type_of_Loan', 'Occupation', 'Monthly_Inhand_Salary', 'Outstanding_Debt']


# Aplicar K-Means com K=3
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(data_for_kmeans)
# Out:
# c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3, random_state=42)

# %%
#Posição dos centroids
print(kmeans.cluster_centers_)
# Out:
# [[ 5.31023918e-02  4.64494591e-01  2.06534923e-01  4.16428529e-01
#   -2.85327317e-14]
#  [ 1.41375992e-01  4.64820089e-01  2.64193240e-01  2.55748394e-01
#    1.00000000e+00]
#  [ 2.16091345e-01  4.68418762e-01  3.42206274e-01  1.60274503e-01
#    2.00000000e+00]]

# %%
#Label dos clusters
labels = kmeans.labels_
data_for_kmeans['Cluster'] = labels


# Hora de plotar o cluster
fig = plt.figure(figsize= (25,15))
ax = fig.add_subplot(111, projection='3d')

x = data_for_kmeans[colunas_kmeans[3]]
y = data_for_kmeans[colunas_kmeans[2]]
z = data_for_kmeans[colunas_kmeans[1]]

cores = ['r', 'g', 'b']
for cluster, cor in enumerate(cores):
    cluster_points = data_for_kmeans[data_for_kmeans['Cluster'] == cluster]
    ax.scatter(cluster_points[colunas_kmeans[3]], cluster_points[colunas_kmeans[2]], cluster_points[colunas_kmeans[1]], c=cor, label=f'Cluster {cluster}')


ax.set_xlabel(colunas_kmeans[3])
ax.set_ylabel(colunas_kmeans[2])
ax.set_zlabel(colunas_kmeans[1])
plt.title('Cluster K-Means (K=3)')
plt.legend()
plt.show()

# %%
df = data_for_kmeans.groupby(['Cluster'], as_index=False).mean()

# %%
###Plotagem para descrever os clusters
sns.barplot(x='Cluster',y='Type_of_Loan',data=df)
# Out:
# <Axes: xlabel='Cluster', ylabel='Type_of_Loan'>

# %%
###Plotagem para descrever os clusters
sns.barplot(x='Cluster',y='Occupation',data=df)
# Out:
# <Axes: xlabel='Cluster', ylabel='Occupation'>

# %%
###Plotagem para descrever os clusters
sns.barplot(x='Cluster',y='Monthly_Inhand_Salary',data=df)
# Out:
# <Axes: xlabel='Cluster', ylabel='Monthly_Inhand_Salary'>

# %%
###Plotagem para descrever os clusters
sns.barplot(x='Cluster',y='Outstanding_Debt',data=df)
# Out:
# <Axes: xlabel='Cluster', ylabel='Outstanding_Debt'>

# %% [markdown]
# #### Descrições do Cluster
# ##### Cluster 0 -> Profissoes que não fizeram nenhum tipo de emprestimo,  possuem renda mensal liquida baixa  e  existe um alto valor de dividas
# ##### Cluster 1 -> Profissoes que fizeram muitos emprestimos , possuem a renda mensal liquida mais alto e  possuem pouco valor de divida
# ##### Cluster 2 -> Profissoes que quase nunca fazem emprestimos, possuem uma boa renda mensal liquida e possuem um valor médio de divida
